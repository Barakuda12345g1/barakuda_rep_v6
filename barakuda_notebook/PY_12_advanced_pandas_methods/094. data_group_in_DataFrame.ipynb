# %% [markdown]
# ## Метод .groupby(<by=>, <axis=>, <as_index=>)

# %%
# импортируюем библиотеку
import pandas as pd


# читаем csv-файл
melb_df = pd.read_csv('data/melb_data_fe.csv', sep=',')
display()

# выводим все предыдущие изменения таблицы
# меняю тип признака
melb_df['Date'] = pd.to_datetime(melb_df['Date'])

# помещаю ряд в переменную для подготовки признака
quarter_column = melb_df['Date'].dt.quarter

# создаю список исключений
exclude_list = ['Date', 'Rooms', 'Bedroom', 'Bathroom', 'Car']
# создаю переменную для фильтрации
max_unique_count = 150
# расматриваем каждый признак
for col in melb_df.columns:
    # условием выбираем нужные признаки
    if melb_df[col].nunique() < max_unique_count and col not in exclude_list:
        melb_df[col] = melb_df[col].astype('category')

# %% [markdown]
# ### Групировка данных по одному критерию с одной агрегацией

# %%
# находим среднее значение числовых типов данных определенного признака
melb_df.groupby(by='Type').mean(numeric_only=True)
# Out:
# /tmp/ipykernel_6751/2079283090.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type').mean(numeric_only=True)
#               Rooms         Price   Distance     Postcode   Bedroom  Bathroom  \
# Type
# house      3.260874  1.242665e+06  10.979479  3104.080643  3.229336  1.613822
# townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183  1.809695
# unit       1.963871  6.051275e+05   7.607391  3110.797481  1.966523  1.183295
#
#                 Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# Type
# house      1.772674  617.181924    152.162553 -37.803795  144.994700
# townhouse  1.555655  279.606822    134.649710 -37.815782  144.996489
# unit       1.128936  477.314219    102.235863 -37.823710  144.996363
#
#            Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# Type
# house        7259.025505        18.996731  -0.490031    55.669700
# townhouse    7094.459605        18.569847  -0.094916    26.690305
# unit         8199.280080        21.068242   0.319883    39.703016

# %%
# введение параметра as_index= даст нам возможность создать сгрупированный 
# признак и проиндексировать таблицу
melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
# Out:
# /tmp/ipykernel_6751/2330189011.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type', as_index=False).mean(numeric_only=True)
#         Type     Rooms         Price   Distance     Postcode   Bedroom  \
# 0      house  3.260874  1.242665e+06  10.979479  3104.080643  3.229336
# 1  townhouse  2.837522  9.337351e+05   9.851346  3100.777379  2.814183
# 2       unit  1.963871  6.051275e+05   7.607391  3110.797481  1.966523
#
#    Bathroom       Car    Landsize  BuildingArea  Lattitude  Longtitude  \
# 0  1.613822  1.772674  617.181924    152.162553 -37.803795  144.994700
# 1  1.809695  1.555655  279.606822    134.649710 -37.815782  144.996489
# 2  1.183295  1.128936  477.314219    102.235863 -37.823710  144.996363
#
#    Propertycount  MeanRoomsSquare  AreaRatio  AgeBuilding
# 0    7259.025505        18.996731  -0.490031    55.669700
# 1    7094.459605        18.569847  -0.094916    26.690305
# 2    8199.280080        21.068242   0.319883    39.703016

# %%
# групируем и находим среднее значение только у одного признака
melb_df.groupby(by='Type')['Price'].mean()
# Out:
# /tmp/ipykernel_6751/701973982.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='Type')['Price'].mean()
# Type
# house        1.242665e+06
# townhouse    9.337351e+05
# unit         6.051275e+05
# Name: Price, dtype: float64

# %%
# найдем минимальное значение расстояния для всех районов города 
melb_df.groupby(by='Regionname', observed=True)['Distance'].min().\
    sort_values(ascending=False)
# Out:
# Regionname
# Western Victoria              29.8
# Eastern Victoria              25.2
# Northern Victoria             21.8
# South-Eastern Metropolitan    14.7
# Eastern Metropolitan           7.8
# Western Metropolitan           4.3
# Southern Metropolitan          0.7
# Northern Metropolitan          0.0
# Name: Distance, dtype: float64

# %% [markdown]
# ### Групировка данных по одному критерию с несколькими агрегациями

# %% [markdown]
# #### .agg()

# %%
# применяем несколько агрегирующиих методов 
melb_df.groupby(by='MonthSale')['Price'].agg(
    ['count', 'mean', 'max']
).sort_values(by='count', ascending=False)
# Out:
# /tmp/ipykernel_6751/3199429698.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='MonthSale')['Price'].agg(
#            count          mean        max
# MonthSale
# 8           1850  1.056371e+06  6500000.0
# 7           1835  9.314698e+05  9000000.0
# 5           1644  1.097807e+06  8000000.0
# 6           1469  1.068981e+06  7650000.0
# 3           1408  1.146762e+06  5600000.0
# 4           1246  1.050479e+06  5500000.0
# 9           1188  1.126349e+06  6400000.0
# 10           854  1.135970e+06  6250000.0
# 11           750  1.142503e+06  5050000.0
# 12           725  1.144737e+06  5700000.0
# 2            333  1.169051e+06  4735000.0
# 1            278  9.397921e+05  5200000.0

# %%
# получаем информацию обо всех статистических характеристиках каждой группы
melb_df.groupby(by='MonthSale')['Price'].agg('describe')
# Out:
# /tmp/ipykernel_6751/2752965871.py:2: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby(by='MonthSale')['Price'].agg('describe')
#             count          mean            std       min       25%        50%  \
# MonthSale
# 1           278.0  9.397921e+05  577668.924214  170000.0  570500.0   795000.0
# 2           333.0  1.169051e+06  671564.357417  131000.0  710000.0  1020000.0
# 3          1408.0  1.146762e+06  709573.596867   85000.0  680000.0   945000.0
# 4          1246.0  1.050479e+06  591892.902979  145000.0  655000.0   905500.0
# 5          1644.0  1.097807e+06  668492.867996  145000.0  650000.0   905000.0
# 6          1469.0  1.068981e+06  606010.069052  222000.0  660000.0   900000.0
# 7          1835.0  9.314698e+05  537390.803161  190000.0  586750.0   800000.0
# 8          1850.0  1.056371e+06  619617.476541  160000.0  635000.0   892000.0
# 9          1188.0  1.126349e+06  608734.690742  170000.0  725000.0   980000.0
# 10          854.0  1.135970e+06  692950.251627  250000.0  652625.0   950000.0
# 11          750.0  1.142503e+06  703666.227892  240000.0  671750.0   950000.0
# 12          725.0  1.144737e+06  706549.007161  250000.0  667500.0   938000.0
#
#                  75%        max
# MonthSale
# 1          1111250.0  5200000.0
# 2          1478000.0  4735000.0
# 3          1400000.0  5600000.0
# 4          1298750.0  5500000.0
# 5          1371250.0  8000000.0
# 6          1325000.0  7650000.0
# 7          1150000.0  9000000.0
# 8          1310000.0  6500000.0
# 9          1360000.0  6400000.0
# 10         1416500.0  6250000.0
# 11         1399125.0  5050000.0
# 12         1412000.0  5700000.0

# %%
# отброжаем информацию о количестве уникальных значениях
# и множество уникальных значений
melb_df.groupby('Regionname')['SellerG'].agg(
    ['nunique', set]
)
# Out:
# /tmp/ipykernel_6751/3169227810.py:3: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   melb_df.groupby('Regionname')['SellerG'].agg(
#                             nunique  \
# Regionname
# Eastern Metropolitan             26
# Eastern Victoria                 11
# Northern Metropolitan            40
# Northern Victoria                11
# South-Eastern Metropolitan       25
# Southern Metropolitan            38
# Western Metropolitan             34
# Western Victoria                  6
#
#                                                                           set
# Regionname
# Eastern Metropolitan        {Fletchers, Marshall, Noel, C21, Gary, Bucking...
# Eastern Victoria            {other, Barry, Fletchers, Eview, HAR, Harcourt...
# Northern Metropolitan       {Eview, Fletchers, Marshall, Hodges, Greg, C21...
# Northern Victoria           {Raine, other, Barry, HAR, LITTLE, McGrath, Ra...
# South-Eastern Metropolitan  {Fletchers, Eview, Chisholm, Gary, Greg, C21, ...
# Southern Metropolitan       {Fletchers, Eview, Chisholm, Marshall, Noel, G...
# Western Metropolitan        {Chisholm, Hodges, Greg, C21, Jas, other, Swee...
# Western Victoria                 {Raine, other, HAR, Ray, YPA, hockingstuart}
