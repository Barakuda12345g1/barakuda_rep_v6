# %% [markdown]
# # Обьекты из классов

# %%
# создаю класс
class SalesReport():
    pass

# создаю обьект по вышепредсталвенному классу
report_1 = SalesReport()
# создаю еще один обьект по классу
report_2 = SalesReport()
# показываю, что обьекты разные
print(report_1 == report_2)
# Out:
# False
